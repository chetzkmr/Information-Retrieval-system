# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
print(GOOGLE_API_KEY)
# Out:
# AIzaSyCOhuDnilfqwRJcDzBlZ2A6OrmUzD6YIMI

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10
